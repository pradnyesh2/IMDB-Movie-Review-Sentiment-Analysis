# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import one_hot

# %%
### Sentences
sent = ['the glass of milk',
        'the glass of juice',
        'the cup of tea',
        'I am a good boy',
        'I am a good developer',
        'understand the meaning of words',
        'your videos are good',]

# %%
## Define the vocabulary size
voc_size=10000

# %%
## One hot representation
one_hot_rep = [one_hot(words,voc_size) for words in sent]
one_hot_rep
# Out:
# [[9086, 5133, 5706, 6457],
#  [9086, 5133, 5706, 3118],
#  [9086, 7057, 5706, 1726],
#  [6471, 8807, 3578, 6000, 9163],
#  [6471, 8807, 3578, 6000, 7830],
#  [7116, 9086, 7484, 5706, 1906],
#  [1188, 5571, 4758, 6000]]

# %%
# Word embedding reprsentation
from tensorflow.keras.layers import Embedding
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import pad_sequences
import numpy as np

# %%
sent_length = 8

# %%
embedded_docs=pad_sequences(one_hot_rep,padding='pre',maxlen=sent_length)
embedded_docs
# Out:
# array([[   0,    0,    0,    0, 9086, 5133, 5706, 6457],
#        [   0,    0,    0,    0, 9086, 5133, 5706, 3118],
#        [   0,    0,    0,    0, 9086, 7057, 5706, 1726],
#        [   0,    0,    0, 6471, 8807, 3578, 6000, 9163],
#        [   0,    0,    0, 6471, 8807, 3578, 6000, 7830],
#        [   0,    0,    0, 7116, 9086, 7484, 5706, 1906],
#        [   0,    0,    0,    0, 1188, 5571, 4758, 6000]], dtype=int32)

# %%
## Feature representation
dim=10

# %%
model=Sequential()
model.add(Embedding(input_dim=voc_size,output_dim=dim))
model.compile(optimizer='adam',loss='mse',metrics=['mse'])

# %%
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_3 (Embedding)         │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.predict(embedded_docs)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# array([[[-2.72571202e-02,  4.85106967e-02, -2.87403110e-02,
#          -4.19310331e-02,  9.80471447e-03, -3.30792554e-02,
#          -2.69785654e-02, -2.57086400e-02, -6.27368689e-03,
#          -1.96750294e-02],
#         [-2.72571202e-02,  4.85106967e-02, -2.87403110e-02,
#          -4.19310331e-02,  9.80471447e-03, -3.30792554e-02,
#          -2.69785654e-02, -2.57086400e-02, -6.27368689e-03,
#          -1.96750294e-02],
#         [-2.72571202e-02,  4.85106967e-02, -2.87403110e-02,
#          -4.19310331e-02,  9.80471447e-03, -3.30792554e-02,
#          -2.69785654e-02, -2.57086400e-02, -6.27368689e-03,
#          -1.96750294e-02],
#         [-2.72571202e-02,  4.85106967e-02, -2.87403110e-02,
#          -4.19310331e-02,  9.80471447e-03, -3.30792554e-02,
#          -2.69785654e-02, -2.57086400e-02, -6.27368689e-03,
#          -1.96750294e-02],
#         [ 7.32010603e-03,  3.89742292e-02,  1.87095255e-03,
#           4.10064571e-02,  2.53702290e-02,  3.09486873e-02,
#          -8.35715607e-03, -4.77094054e-02,  4.76009734e-02,
#          -4.24803607e-02],
#         [ 3.94795872e-02, -1.39252059e-02, -1.61560662e-02,
#          -4.69327942e-02,  3.33372690e-02, -3.51128094e-02,
#          -3.13576944e-02,  1.94148086e-02,  3.15495022e-02,
#           3.82008813e-02],
#         [-3.82329337e-02,  2.95688771e-02,  2.24429108e-02,
#           1.61402263e-02, -3.84793058e-02,  3.35323475e-02,
#           3.48703153e-02,  2.31264271e-02, -4.97955941e-02,
#          -4.40984480e-02],
#         [ 4.68044356e-03, -3.02110072e-02, -1.57083645e-02,
#           1.74373873e-02,  1.57080777e-02,  6.04786724e-03,
#           5.14947250e-03,  9.79468971e-03, -4.73141335e-02,
#           3.30900289e-02]],
#
#        [[-2.72571202e-02,  4.85106967e-02, -2.87403110e-02,
#          -4.19310331e-02,  9.80471447e-03, -3.30792554e-02,
#          -2.69785654e-02, -2.57086400e-02, -6.27368689e-03,
#          -1.96750294e-02],
#         [-2.72571202e-02,  4.85106967e-02, -2.87403110e-02,
#          -4.19310331e-02,  9.80471447e-03, -3.30792554e-02,
#          -2.69785654e-02, -2.57086400e-02, -6.27368689e-03,
#          -1.96750294e-02],
#         [-2.72571202e-02,  4.85106967e-02, -2.87403110e-02,
#          -4.19310331e-02,  9.80471447e-03, -3.30792554e-02,
#          -2.69785654e-02, -2.57086400e-02, -6.27368689e-03,
#          -1.96750294e-02],
#         [-2.72571202e-02,  4.85106967e-02, -2.87403110e-02,
#          -4.19310331e-02,  9.80471447e-03, -3.30792554e-02,
#          -2.69785654e-02, -2.57086400e-02, -6.27368689e-03,
#          -1.96750294e-02],
#         [ 7.32010603e-03,  3.89742292e-02,  1.87095255e-03,
#           4.10064571e-02,  2.53702290e-02,  3.09486873e-02,
#          -8.35715607e-03, -4.77094054e-02,  4.76009734e-02,
#          -4.24803607e-02],
#         [ 3.94795872e-02, -1.39252059e-02, -1.61560662e-02,
#          -4.69327942e-02,  3.33372690e-02, -3.51128094e-02,
#          -3.13576944e-02,  1.94148086e-02,  3.15495022e-02,
#           3.82008813e-02],
#         [-3.82329337e-02,  2.95688771e-02,  2.24429108e-02,
#           1.61402263e-02, -3.84793058e-02,  3.35323475e-02,
#           3.48703153e-02,  2.31264271e-02, -4.97955941e-02,
#          -4.40984480e-02],
#         [ 8.37196037e-03, -4.11795862e-02, -2.20005270e-02,
#          -2.11666822e-02,  3.30706574e-02,  3.79232205e-02,
#           1.30582601e-04,  3.68954577e-02, -2.01881174e-02,
#           2.97395699e-02]],
#
#        [[-2.72571202e-02,  4.85106967e-02, -2.87403110e-02,
#          -4.19310331e-02,  9.80471447e-03, -3.30792554e-02,
#          -2.69785654e-02, -2.57086400e-02, -6.27368689e-03,
#          -1.96750294e-02],
#         [-2.72571202e-02,  4.85106967e-02, -2.87403110e-02,
#          -4.19310331e-02,  9.80471447e-03, -3.30792554e-02,
#          -2.69785654e-02, -2.57086400e-02, -6.27368689e-03,
#          -1.96750294e-02],
#         [-2.72571202e-02,  4.85106967e-02, -2.87403110e-02,
#          -4.19310331e-02,  9.80471447e-03, -3.30792554e-02,
#          -2.69785654e-02, -2.57086400e-02, -6.27368689e-03,
#          -1.96750294e-02],
#         [-2.72571202e-02,  4.85106967e-02, -2.87403110e-02,
#          -4.19310331e-02,  9.80471447e-03, -3.30792554e-02,
#          -2.69785654e-02, -2.57086400e-02, -6.27368689e-03,
#          -1.96750294e-02],
#         
0.02725712,  0.0485107 , -0.02874031, -0.04193103,
#           0.00980471, -0.03307926, -0.02697857, -0.02570864,
#          -0.00627369, -0.01967503],
#         [-0.02725712,  0.0485107 , -0.02874031, -0.04193103,
#           0.00980471, -0.03307926, -0.02697857, -0.02570864,
#          -0.00627369, -0.01967503],
#         [-0.02725712,  0.0485107 , -0.02874031, -0.04193103,
#           0.00980471, -0.03307926, -0.02697857, -0.02570864,
#          -0.00627369, -0.01967503],
#         [-0.02725712,  0.0485107 , -0.02874031, -0.04193103,
#           0.00980471, -0.03307926, -0.02697857, -0.02570864,
#          -0.00627369, -0.01967503],
#         [ 0.00732011,  0.03897423,  0.00187095,  0.04100646,
#           0.02537023,  0.03094869, -0.00835716, -0.04770941,
#           0.04760097, -0.04248036],
#         [ 0.03947959, -0.01392521, -0.01615607, -0.04693279,
#           0.03333727, -0.03511281, -0.03135769,  0.01941481,
#           0.0315495 ,  0.03820088],
#         [-0.03823293,  0.02956888,  0.02244291,  0.01614023,
#          -0.03847931,  0.03353235,  0.03487032,  0.02312643,
#          -0.04979559, -0.04409845],
#         [ 0.00468044, -0.03021101, -0.01570836,  0.01743739,
#           0.01570808,  0.00604787,  0.00514947,  0.00979469,
#          -0.04731413,  0.03309003]]], dtype=float32)

# %%
the = np.array([[0, 0, 0, 0, 9086, 5133, 5706, 6457]])

# %%
the
# Out:
# array([[   0,    0,    0,    0, 9086, 5133, 5706, 6457]])

# %%
model.predict(the)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# array([[[-0.02725712,  0.0485107 , -0.02874031, -0.04193103,
#           0.00980471, -0.03307926, -0.02697857, -0.02570864,
#          -0.00627369, -0.01967503],
#         [-0.02725712,  0.0485107 , -0.02874031, -0.04193103,
#           0.00980471, -0.03307926, -0.02697857, -0.02570864,
#          -0.00627369, -0.01967503],
#         [-0.02725712,  0.0485107 , -0.02874031, -0.04193103,
#           0.00980471, -0.03307926, -0.02697857, -0.02570864,
#          -0.00627369, -0.01967503],
#         [-0.02725712,  0.0485107 , -0.02874031, -0.04193103,
#           0.00980471, -0.03307926, -0.02697857, -0.02570864,
#          -0.00627369, -0.01967503],
#         [ 0.00732011,  0.03897423,  0.00187095,  0.04100646,
#           0.02537023,  0.03094869, -0.00835716, -0.04770941,
#           0.04760097, -0.04248036],
#         [ 0.03947959, -0.01392521, -0.01615607, -0.04693279,
#           0.03333727, -0.03511281, -0.03135769,  0.01941481,
#           0.0315495 ,  0.03820088],
#         [-0.03823293,  0.02956888,  0.02244291,  0.01614023,
#          -0.03847931,  0.03353235,  0.03487032,  0.02312643,
#          -0.04979559, -0.04409845],
#         [ 0.00468044, -0.03021101, -0.01570836,  0.01743739,
#           0.01570808,  0.00604787,  0.00514947,  0.00979469,
#          -0.04731413,  0.03309003]]], dtype=float32)

# %%
doc1=embedded_docs[[0]]
doc1
# Out:
# array([[   0,    0,    0,    0, 9086, 5133, 5706, 6457]], dtype=int32)

# %%
model.predict(doc1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# array([[[-0.02725712,  0.0485107 , -0.02874031, -0.04193103,
#           0.00980471, -0.03307926, -0.02697857, -0.02570864,
#          -0.00627369, -0.01967503],
#         [-0.02725712,  0.0485107 , -0.02874031, -0.04193103,
#           0.00980471, -0.03307926, -0.02697857, -0.02570864,
#          -0.00627369, -0.01967503],
#         [-0.02725712,  0.0485107 , -0.02874031, -0.04193103,
#           0.00980471, -0.03307926, -0.02697857, -0.02570864,
#          -0.00627369, -0.01967503],
#         [-0.02725712,  0.0485107 , -0.02874031, -0.04193103,
#           0.00980471, -0.03307926, -0.02697857, -0.02570864,
#          -0.00627369, -0.01967503],
#         [ 0.00732011,  0.03897423,  0.00187095,  0.04100646,
#           0.02537023,  0.03094869, -0.00835716, -0.04770941,
#           0.04760097, -0.04248036],
#         [ 0.03947959, -0.01392521, -0.01615607, -0.04693279,
#           0.03333727, -0.03511281, -0.03135769,  0.01941481,
#           0.0315495 ,  0.03820088],
#         [-0.03823293,  0.02956888,  0.02244291,  0.01614023,
#          -0.03847931,  0.03353235,  0.03487032,  0.02312643,
#          -0.04979559, -0.04409845],
#         [ 0.00468044, -0.03021101, -0.01570836,  0.01743739,
#           0.01570808,  0.00604787,  0.00514947,  0.00979469,
#          -0.04731413,  0.03309003]]], dtype=float32)

# %%
test = model.predict(embedded_docs[[0]])
test
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# array([[[-0.02725712,  0.0485107 , -0.02874031, -0.04193103,
#           0.00980471, -0.03307926, -0.02697857, -0.02570864,
#          -0.00627369, -0.01967503],
#         [-0.02725712,  0.0485107 , -0.02874031, -0.04193103,
#           0.00980471, -0.03307926, -0.02697857, -0.02570864,
#          -0.00627369, -0.01967503],
#         [-0.02725712,  0.0485107 , -0.02874031, -0.04193103,
#           0.00980471, -0.03307926, -0.02697857, -0.02570864,
#          -0.00627369, -0.01967503],
#         [-0.02725712,  0.0485107 , -0.02874031, -0.04193103,
#           0.00980471, -0.03307926, -0.02697857, -0.02570864,
#          -0.00627369, -0.01967503],
#         [ 0.00732011,  0.03897423,  0.00187095,  0.04100646,
#           0.02537023,  0.03094869, -0.00835716, -0.04770941,
#           0.04760097, -0.04248036],
#         [ 0.03947959, -0.01392521, -0.01615607, -0.04693279,
#           0.03333727, -0.03511281, -0.03135769,  0.01941481,
#           0.0315495 ,  0.03820088],
#         [-0.03823293,  0.02956888,  0.02244291,  0.01614023,
#          -0.03847931,  0.03353235,  0.03487032,  0.02312643,
#          -0.04979559, -0.04409845],
#         [ 0.00468044, -0.03021101, -0.01570836,  0.01743739,
#           0.01570808,  0.00604787,  0.00514947,  0.00979469,
#          -0.04731413,  0.03309003]]], dtype=float32)

# %%
test.shape
# Out:
# (1, 8, 10)
